# %% [markdown]
# <a href="https://colab.research.google.com/github/MashaaX/PCVK_Genap_20-21/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/rick-astley-social.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/rick-astley-social.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(384,0),pt2=(501,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(400,400), radius=50, color=(255,0,0), thickness = -1)

cv.line(black_img, pt1=(0,0), pt2=(512,512), color=(255,255,255), thickness = 5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %%
imgGreen = img
imgGreen[:,:,0] = 0
imgGreen[:,:,2] = 0
plt.imshow(img)

# %%
croppedImg = img[5:30,0:500]
croppedImg[:,:,0] = 0
croppedImg[:,:,2] = 0

plt.imshow(croppedImg)

# %%
fig = plt.figure(figsize=(10,10))
plt.imshow(img)

# %%
rand_rect_img = cv.imread('/content/drive/MyDrive/rick-astley-social.jpg')
rand_rect_img = cv.cvtColor(rand_rect_img, cv.COLOR_BGR2RGB)

width = rand_rect_img.shape[1]
height = rand_rect_img.shape[0]

for i in range(5):
  rd_height1 = rd.randint(0, height)
  rd_width1 = rd.randint(0, width)
  rd_height2 = rd.randint(0, height)
  rd_width2 = rd.randint(0, width)
  rd_R = rd.randint(0, 255)
  rd_G = rd.randint(0, 255)
  rd_B = rd.randint(0, 255)
  cv.rectangle(rand_rect_img, pt1 = (rd_width1, rd_height1), 
               pt2 = (rd_width2, rd_height2),
               color = (rd_R,rd_G,rd_B), thickness = 10)

plt.imshow(rand_rect_img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-e30e1a78d962> in <module>()
#       6
#       7 for i in range(5):
# ----> 8   rd_height1 = rd.randint(0, height)
#       9   rd_width1 = rd.randint(0, width)
#      10   rd_height2 = rd.randint(0, height)
#
# NameError: name 'rd' is not defined
